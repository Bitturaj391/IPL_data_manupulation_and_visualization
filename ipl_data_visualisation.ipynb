# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
Match = pd.read_csv('Match.csv')
Match.head()
# Out:
#    Match_SK  match_id                        Team1  \
# 0         0    335987  Royal Challengers Bangalore
# 1         1    335988              Kings XI Punjab
# 2         2    335989             Delhi Daredevils
# 3         3    335990               Mumbai Indians
# 4         4    335991        Kolkata Knight Riders
#
#                          Team2 match_date  Season_Year  \
# 0        Kolkata Knight Riders  4/18/2008         2008
# 1          Chennai Super Kings  4/19/2008         2008
# 2             Rajasthan Royals  4/19/2008         2008
# 3  Royal Challengers Bangalore  4/20/2008         2008
# 4              Deccan Chargers  4/20/2008         2008
#
#                                    Venue_Name   City_Name Country_Name  \
# 0                       M Chinnaswamy Stadium   Bangalore        India
# 1  Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 2                            Feroz Shah Kotla       Delhi        India
# ...

# %%
Match['ManOfMach'].value_counts()
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# SK Raina          14
#                   ..
# CL White           1
# S Sreesanth        1
# M Kartik           1
# Umar Gul           1
# DP Nannes          1
# Name: ManOfMach, Length: 202, dtype: int64

# %%
manofthematch = Match['ManOfMach'].value_counts()[0:10]
manofthematch
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# SK Raina          14
# RG Sharma         14
# G Gambhir         13
# MS Dhoni          13
# MEK Hussey        12
# AM Rahane         12
# Name: ManOfMach, dtype: int64

# %%
No_match_year=Match['Season_Year'].value_counts()
No_match_year
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2017    60
# 2015    59
# 2008    58
# 2009    57
# Name: Season_Year, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.distplot(Match['Season_Year'])
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.barplot(x='Country_Name',y='Season_Year',data=Match)
plt.show()

# %%
Match['Country_Name'].value_counts()
# Out:
# India           560
# South Africa     57
# U.A.E            20
# Name: Country_Name, dtype: int64

# %%
sns.distplot(Match["Country_id"])
plt.show()

# %%
sns.distplot(Match['Win_Margin'])
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
Match['City_Name'].value_counts()
# Out:
# Mumbai                85
# Kolkata               61
# Delhi                 60
# Bangalore             58
# Chennai               48
# Chandigarh            42
# Hyderabad             41
# Jaipur                33
# Pune                  32
# Abu Dhabi             20
# Durban                15
# Centurion             12
# Ahmedabad             12
# Visakhapatnam         11
# Rajkot                10
# Dharamsala             9
# Bengaluru              9
# Johannesburg           8
# Hyderabad (Deccan)     8
# Cuttack                7
# Port Elizabeth         7
# Ranchi                 7
# Cape Town              7
# Raipur                 6
# Indore                 5
# Kochi                  5
# Kanpur                 4
# Mohali                 4
# Nagpur                 3
# Kimberley              3
# East London            3
# Bloemfontein           2
# Name: City_Name, dtype: int64

# %%
Match['Toss_Winner'].value_counts()
# Out:
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Rising Pune Supergiants        12
# Kochi Tuskers Kerala            8
# Rising Pune Supergiant          1
# Name: Toss_Winner, dtype: int64

# %%
plt.figure(figsize=(30,8))
sns.scatterplot(x='Toss_Winner',y='Win_Margin',data=Match)
plt.show()

# %%
Match['Outcome_Type'].value_counts()
# Out:
# Result       626
# Superover      6
# No Result      3
# tied           1
# abandoned      1
# Name: Outcome_Type, dtype: int64

# %%
Match['ManOfMach'].value_counts()[0:5].keys()
# Out:
# Index(['CH Gayle', 'YK Pathan', 'AB de Villiers', 'DA Warner', 'SK Raina'], dtype='object')

# %%
list(Match['ManOfMach'].value_counts()[0:5].keys())
# Out:
# ['CH Gayle', 'YK Pathan', 'AB de Villiers', 'DA Warner', 'SK Raina']

# %%
plt.bar(list(Match['ManOfMach'].value_counts()[0:5].keys()),list(Match['ManOfMach'].value_counts()[0:5]),color='g')
plt.show()

# %%
sns.barplot(x=list(Match['Outcome_Type'].value_counts().keys()),y=list(Match['Outcome_Type'].value_counts()),data=Match)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=list(Match['City_Name'].value_counts()[0:10].keys()),y=list(Match['City_Name'].value_counts()[0:10]))
plt.show()

# %%
Match['Toss_Winner'].value_counts()
# Out:
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Rising Pune Supergiants        12
# Kochi Tuskers Kerala            8
# Rising Pune Supergiant          1
# Name: Toss_Winner, dtype: int64

# %%
batting_first = Match[Match['Win_Type']=="runs"]
batting_first.head()
# Out:
#     Match_SK  match_id                        Team1                  Team2  \
# 0          0    335987  Royal Challengers Bangalore  Kolkata Knight Riders
# 1          1    335988              Kings XI Punjab    Chennai Super Kings
# 7          7    335994          Chennai Super Kings         Mumbai Indians
# 9          9    335996              Kings XI Punjab         Mumbai Indians
# 14        14    336001  Royal Challengers Bangalore    Chennai Super Kings
#
#    match_date  Season_Year                                  Venue_Name  \
# 0   4/18/2008         2008                       M Chinnaswamy Stadium
# 1   4/19/2008         2008  Punjab Cricket Association Stadium, Mohali
# 7   4/23/2008         2008             MA Chidambaram Stadium, Chepauk
# 9   4/25/2008         2008  Punjab Cricket Association Stadium, Mohali
# 14  4/28/2008         2008                       M Chinnaswamy Stadium
#
#      City_Name Country_Name                  Toss_Winner  \
# ...

# %%
plt.hist(batting_first['Win_Margin'])
plt.title("Distrubution of runs")
plt.xlabel("Runs")
plt.ylabel("No_Matches")
plt.show()

# %%
batting_first['match_winner'].value_counts()
# Out:
# Chennai Super Kings            46
# Mumbai Indians                 46
# Kings XI Punjab                32
# Kolkata Knight Riders          31
# Royal Challengers Bangalore    30
# Sunrisers Hyderabad            23
# Rajasthan Royals               23
# Delhi Daredevils               21
# Deccan Chargers                18
# Rising Pune Supergiants         7
# Pune Warriors                   6
# Kochi Tuskers Kerala            2
# Gujarat Lions                   1
# Name: match_winner, dtype: int64

# %%
plt.figure(figsize=(25,5))
sns.barplot(x=list(batting_first['match_winner'].value_counts()[0:10].keys()),y=list(batting_first['match_winner'].value_counts()[0:10]))
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.barplot(x=list(Match['match_winner'].value_counts()[0:10].keys()),y=list(Match['match_winner'].value_counts()[0:10]))
plt.show()

# %%
Match['match_winner'].value_counts()
# Out:
# Mumbai Indians                 91
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Rising Pune Supergiants        15
# Gujarat Lions                  13
# Pune Warriors                  12
# Kochi Tuskers Kerala            6
# tied                            1
# abandoned                       1
# Name: match_winner, dtype: int64

# %%
plt.pie(list(batting_first['match_winner'].value_counts()[0:5]),labels=list(batting_first['match_winner'].value_counts()[0:5].keys()),autopct='%0.1f%%',colors=['yellow','red','green','blue','olive'])
plt.show()

# %%
plt.pie(list(Match['match_winner'].value_counts()[0:10]),labels=list(Match['match_winner'].value_counts()[0:10].keys()),autopct='%0.1f%%')
plt.show()

# %%
Team1 = Match['Team1'].value_counts()
Team1
# Out:
# Royal Challengers Bangalore    85
# Delhi Daredevils               76
# Chennai Super Kings            74
# Mumbai Indians                 72
# Kings XI Punjab                72
# Kolkata Knight Riders          69
# Rajasthan Royals               52
# Deccan Chargers                39
# Sunrisers Hyderabad            38
# Pune Warriors                  23
# Gujarat Lions                  16
# Rising Pune Supergiants        14
# Kochi Tuskers Kerala            7
# Name: Team1, dtype: int64

# %%
plt.figure(figsize=(30,5))
plt.bar(list(Match['Team1'].value_counts().keys()),list(Match['Team1'].value_counts()))
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=list(Match['Team1'].value_counts()[0:10].keys()),y=list(Match['Team1'].value_counts()[0:10]),data=Match)
plt.show()

# %%
TossWinner_values = list(Match['Toss_Winner'].value_counts())
TossWinner_values
# Out:
# [85, 78, 72, 70, 68, 66, 63, 43, 35, 20, 15, 12, 8, 1]
